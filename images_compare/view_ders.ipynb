# %%
from IPython.display import Image

# %%
Image(filename="../images2/mag_increasing_with_x_andy.png")

# %%
Image(filename="../images/bowl.png")

# %%
Image(filename="mag_increasing_with_x_drk.png")

# %%
Image(filename="../images_compare/mag_increasing_with_y_andy.png")

# %%
Image(filename="mag_increasing_with_y_marshall.png")

# %%
Image(filename="mag_increasing_with_y_drk.png")

# %%
Image(filename="mag_increasing_diag_upright_andy.png")

# %%
Image(filename="mag_increasing_diag_upright_marshall.png")

# %%
Image(filename="mag_increasing_diag_upright_drk.png")

# %%
Image(filename="mag_increasing_diag_downright_andy.png")

# %%
Image(filename="mag_increasing_diag_downright_marshall.png")

# %%
Image(filename="mag_increasing_diag_downright_drk.png")

# %%
Image(filename="random_andy.png")

# %%
Image(filename="random_marshall.png")

# %%
Image(filename="random_drk.png")
