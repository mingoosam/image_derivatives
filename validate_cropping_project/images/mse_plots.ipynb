# %%
from IPython.display import Image

# %%
Image('mse_Image_0.png')

# %%
Image('mse_Image_1.png')

# %%
Image('mse_Image_2.png')

# %%
Image('mse_Image_3.png')

# %%
Image('mse_Image_4.png')

# %%
Image('mse_Image_5.png')

# %%
Image('mse_Image_6.png')

# %%
Image('mse_Image_7.png')

# %%
Image('mse_Image_8.png')

# %%
Image('mse_Image_9.png')

# %%
Image('mse_Image_phase_0.png')

# %%
Image('mse_Image_phase_1.png')

# %%
Image('mse_Image_phase_2.png')

# %%
Image('mse_Image_phase_3.png')

# %%
Image('mse_Image_phase_4.png')

# %%
Image('mse_Image_phase_5.png')

# %%
Image('mse_Image_phase_6.png')

# %%
Image('mse_Image_phase_7.png')

# %%
Image('mse_Image_phase_8.png')

# %%
Image('mse_Image_phase_9.png')
